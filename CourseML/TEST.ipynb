# %%
import pandas as pd
import numpy as np
np.random.seed(42)
data = np.random.randint(0,101,(3,3))
indices = ("Sasha", "Pasha", "Vitya")
columns = ("Weight", "Height","Penis")
first_data_frame = pd.DataFrame(data, indices, columns)
first_data_frame
# Out:
#        Weight  Height  Penis
# Sasha      51      92     14
# Pasha      71      60     20
# Vitya      82      86     74

# %%
first_data_frame = pd.read_csv("C:\\Users\\aleks\\Desktop\\courseML\\03-Pandas\\tips.csv")
first_data_frame[first_data_frame['day'].isin(['Sat',"Fri"])]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 19        20.65  3.35    Male     No  Sat  Dinner     3              6.88
# 20        17.92  4.08    Male     No  Sat  Dinner     2              8.96
# 21        20.29  2.75  Female     No  Sat  Dinner     2             10.14
# 22        15.77  2.23  Female     No  Sat  Dinner     2              7.88
# 23        39.42  7.58    Male     No  Sat  Dinner     4              9.86
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#           Payer Name         CC Number Payment ID
# ...

# %%
first_data_frame["2x_total_bill"] =np.round(2 *  first_data_frame['total_bill'],0)
first_data_frame = first_data_frame.set_index("Payment ID")
first_data_frame.tail(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19124\3466487290.py in <module>
# ----> 1 first_data_frame["2x_total_bill"] =np.round(2 *  first_data_frame['total_bill'],0)
#       2 first_data_frame = first_data_frame.set_index("Payment ID")
#       3 first_data_frame.tail(10)
#
# D:\anaconda\envs\requirements_course\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if (
#
# D:\anaconda\envs\requirements_course\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     989
#     990         # Similar to Index.get_value, but we do not fall back to positional
# --> 991         loc = self.index.get_loc(label)
#     992         return self.index._get_values_for_loc(self, loc, label)
# ...

# %%
first_data_frame.drop('Sat17')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
def foo (bill):
    bill = int(bill)
    if bill <= 10 :
        return '$'
    elif  bill < 25:
        return '$$'
    else :
        return '$$$'

# %%
first_data_frame['yelp'] = first_data_frame['total_bill'].apply(foo)
first_data_frame[first_data_frame['yelp'] == '$$$']
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 5         25.29   4.71    Male     No   Sun  Dinner     4              6.32
# 7         26.88   3.12    Male     No   Sun  Dinner     4              6.72
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 48        28.55   2.05    Male     No   Sun  Dinner     3              9.52
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 54        25.56   4.34    Male     No   Sun  Dinner     4              6.39
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# ...

# %%
#08.11.23
first_data_frame['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
first_data_frame['sex'].replace(['Female','Male'],['f','m'])
# Out:
# 0      f
# 1      m
# 2      m
# 3      m
# 4      f
#       ..
# 239    m
# 240    f
# 241    m
# 242    m
# 243    f
# Name: sex, Length: 244, dtype: object

# %%
mymap = {'Female':'f', 'Male':'m'}
first_data_frame['sex'].map(mymap)
# Out:
# 0      f
# 1      m
# 2      m
# 3      m
# 4      f
#       ..
# 239    m
# 240    f
# 241    m
# 242    m
# 243    f
# Name: sex, Length: 244, dtype: object
