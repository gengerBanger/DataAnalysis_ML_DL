# %%
import numpy as np
import pandas as pd

from datetime import datetime

# %%
group = pd.read_csv('C:\\Users\\aleks\\Desktop\\courseML\\03-Pandas\\mpg.csv')
aye = group.groupby(['model_year','cylinders']).mean()

# %%
aye
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
aye.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
aye.xs(key = 80)
# Out:
#               mpg  displacement   weight  acceleration  origin
# cylinders
# 3          23.700          70.0  2420.00        12.500     3.0
# 4          34.612         111.0  2360.08        17.144     2.2
# 5          36.400         121.0  2950.00        19.900     2.0
# 6          25.900         196.5  3145.50        15.050     2.0

# %%
group[group['cylinders'].isin([6,8])]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 365  20.2          6         200.0         88    3060          17.1
# 366  17.6          6         225.0         85    3465          16.6
# 386  25.0          6         181.0        110    2945          16.4
# 387  38.0          6         262.0         85    3015          17.0
# 389  22.0          6         232.0        112    2835          14.7
#
#      model_year  origin                               name
# 0            70       1          chevrolet chevelle malibu
# ...

# %% [raw]
# pop = group.groupby(['model_year','cylinders']).mean()
# pop

# %%
pop = group[group['cylinders'].isin([6,8])].groupby(['model_year','cylinders']).mean()
pop
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 73         6          19.000000    212.250000  2917.125000     15.687500
#            8          13.200000    365.250000  4279.050000     12.250000
# 74         6          17.857143    230.428571  3320.000000     16.857143
#            8          14.200000    315.200000  4438.400000     14.700000
# 75         6          17.583333    233.750000  3398.333333     17.708333
#            8          15.666667    330.500000  4108.833333     13.166667
# ...

# %%
#string methods
names = pd.Series(['andrew','bobo','claire','david','5'])

# %%
names
# Out:
# 0    andrew
# 1      bobo
# 2    claire
# 3     david
# 4         5
# dtype: object

# %%
names.str.upper()
# Out:
# 0    ANDREW
# 1      BOBO
# 2    CLAIRE
# 3     DAVID
# 4         5
# dtype: object

# %%
names.str.lower()
# Out:
# 0    andrew
# 1      bobo
# 2    claire
# 3     david
# 4         5
# dtype: object

# %%
tech_finance = ['GOOG,APPL,AMZN','JPN,BAC,GS']
tickers = pd.Series(tech_finance)

# %%
tickers = tickers.str.split(',', expand=True)

# %%
tickers.columns = ['-','=','+']

# %%
tickers.set_index = ['-']

# %%
tickers
# Out:
#       -     =     +
# 0  GOOG  APPL  AMZN
# 1   JPN   BAC    GS

# %%
#data&time
myyear = 2015
mymonth = 7
myday = 9 
myhour = 15
mymin = 30
mesec = 1

# %%
mydate = datetime(myyear,mymonth,myday)
mydate
# Out:
# datetime.datetime(2015, 7, 9, 0, 0)

# %%
sales = pd.read_csv('C:\\Users\\aleks\\Desktop\\courseML\\03-Pandas\\RetailSales_BeerWineLiquor.csv', parse_dates = [0])

# %%
sales['DATE']
# Out:
# 0     1992-01-01
# 1     1992-02-01
# 2     1992-03-01
# 3     1992-04-01
# 4     1992-05-01
#          ...
# 335   2019-12-01
# 336   2020-01-01
# 337   2020-02-01
# 338   2020-03-01
# 339   2020-04-01
# Name: DATE, Length: 340, dtype: datetime64[ns]
